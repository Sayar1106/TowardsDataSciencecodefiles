# %% [markdown]
# # Handling Missing Values in Python

# %% [markdown]
# ## Loading Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Reading Data

# %%
## Reading in data
diabetes = pd.read_csv('diabetes.csv')

# %%
diabetes.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
# 5                     0.201   30        0
# 6                     0.248   26        1
# 7                     0.134   29        0
# 8                     0.158   53        1
# 9                     0.232   54        1

# %%
# Dropping target variable
diabetes.drop(columns=['Outcome'], axis=1, inplace = True)

diabetes.shape
# Out:
# (768, 8)

# %%
diabetes.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# dtype: int64

# %%
# Inserting missing values
diabetes_missing = diabetes.mask(np.random.random(diabetes.shape) < 0.1)

# %%
diabetes_missing.isnull().sum()
# Out:
# Pregnancies                 70
# Glucose                     91
# BloodPressure               62
# SkinThickness               86
# Insulin                     82
# BMI                         85
# DiabetesPedigreeFunction    78
# Age                         82
# dtype: int64

# %%
diabetes_missing.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          NaN    148.0            NaN            NaN      0.0  33.6
# 1          1.0     85.0           66.0           29.0      0.0  26.6
# 2          8.0    183.0           64.0            NaN      0.0  23.3
# 3          1.0     89.0           66.0           23.0     94.0  28.1
# 4          0.0    137.0           40.0           35.0      NaN  43.1
# 5          5.0    116.0            NaN            NaN      0.0  25.6
# 6          3.0     78.0           50.0           32.0      NaN  31.0
# 7         10.0    115.0            0.0            0.0      0.0  35.3
# 8          2.0    197.0           70.0            NaN    543.0  30.5
# 9          8.0    125.0           96.0            0.0      0.0   0.0
#
#    DiabetesPedigreeFunction   Age
# 0                     0.627   NaN
# 1                     0.351  31.0
# 2                     0.672  32.0
# 3                     0.167  21.0
# 4                     2.288  33.0
# 5                       NaN  30.0
# 6                     0.248  26.0
# 7                     0.134  29.0
# 8                     0.158  53.0
# 9                     0.232  54.0

# %% [markdown]
# ## Listwise Deletion

# %%
diabetes_remove = diabetes_missing.dropna(axis=0)

diabetes_remove.shape
# Out:
# (324, 8)

# %% [markdown]
# ## Zero Value Imputation

# %%
diabetes_0 = diabetes_missing.fillna(0)

diabetes_0.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          0.0    148.0            0.0            0.0      0.0  33.6
# 1          1.0     85.0           66.0           29.0      0.0  26.6
# 2          8.0    183.0           64.0            0.0      0.0  23.3
# 3          1.0     89.0           66.0           23.0     94.0  28.1
# 4          0.0    137.0           40.0           35.0      0.0  43.1
# 5          5.0    116.0            0.0            0.0      0.0  25.6
# 6          3.0     78.0           50.0           32.0      0.0  31.0
# 7         10.0    115.0            0.0            0.0      0.0  35.3
# 8          2.0    197.0           70.0            0.0    543.0  30.5
# 9          8.0    125.0           96.0            0.0      0.0   0.0
#
#    DiabetesPedigreeFunction   Age
# 0                     0.627   0.0
# 1                     0.351  31.0
# 2                     0.672  32.0
# 3                     0.167  21.0
# 4                     2.288  33.0
# 5                     0.000  30.0
# 6                     0.248  26.0
# 7                     0.134  29.0
# 8                     0.158  53.0
# 9                     0.232  54.0

# %% [markdown]
# ## Central Value Imputation

# %%
from sklearn.impute import SimpleImputer

# %%
num_imputer = SimpleImputer(missing_values=np.nan, strategy='mean')

# %%
vals = diabetes_missing.values

# %%
vals
# Out:
# array([[    nan, 148.   ,     nan, ...,  33.6  ,   0.627,     nan],
#        [  1.   ,  85.   ,  66.   , ...,  26.6  ,   0.351,  31.   ],
#        [  8.   , 183.   ,  64.   , ...,  23.3  ,   0.672,  32.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,  26.2  ,   0.245,  30.   ],
#        [  1.   , 126.   ,  60.   , ...,  30.1  ,     nan,  47.   ],
#        [  1.   ,  93.   ,  70.   , ...,  30.4  ,   0.315,  23.   ]])

# %%
# Fit imputer to data to retrieve central measure:
num_imputer.fit(vals)
# Out:
# SimpleImputer(add_indicator=False, copy=True, fill_value=None,
#               missing_values=nan, strategy='mean', verbose=0)

# %%
# Transforming missing data points to mean value:
num_imputer.transform(vals)
# Out:
# array([[  3.82808023, 148.        ,  69.18838527, ...,  33.6       ,
#           0.627     ,  33.44169096],
#        [  1.        ,  85.        ,  66.        , ...,  26.6       ,
#           0.351     ,  31.        ],
#        [  8.        , 183.        ,  64.        , ...,  23.3       ,
#           0.672     ,  32.        ],
#        ...,
#        [  5.        , 121.        ,  72.        , ...,  26.2       ,
#           0.245     ,  30.        ],
#        [  1.        , 126.        ,  60.        , ...,  30.1       ,
#           0.46682174,  47.        ],
#        [  1.        ,  93.        ,  70.        , ...,  30.4       ,
#           0.315     ,  23.        ]])

# %%
diabetes_missing.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          NaN    148.0            NaN            NaN      0.0  33.6
# 1          1.0     85.0           66.0           29.0      0.0  26.6
# 2          8.0    183.0           64.0            NaN      0.0  23.3
# 3          1.0     89.0           66.0           23.0     94.0  28.1
# 4          0.0    137.0           40.0           35.0      NaN  43.1
# 5          5.0    116.0            NaN            NaN      0.0  25.6
# 6          3.0     78.0           50.0           32.0      NaN  31.0
# 7         10.0    115.0            0.0            0.0      0.0  35.3
# 8          2.0    197.0           70.0            NaN    543.0  30.5
# 9          8.0    125.0           96.0            0.0      0.0   0.0
#
#    DiabetesPedigreeFunction   Age
# 0                     0.627   NaN
# 1                     0.351  31.0
# 2                     0.672  32.0
# 3                     0.167  21.0
# 4                     2.288  33.0
# 5                       NaN  30.0
# 6                     0.248  26.0
# 7                     0.134  29.0
# 8                     0.158  53.0
# 9                     0.232  54.0
